# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %run spotify_wrangling.ipynb

# %%
# Dataset has been wrangled in spotify_wrangling.ipynb - Imported from 'spotify-largest.csv' 
# df = pd.read_csv("spotify-largeset.csv")
df = pd.read_csv("data/data_w_genres.csv")
data = pd.read_csv("data/spotify-largeset.csv")

# %%
#  Only keeping continuous variables
# df.drop(['artists', 'name', 'Tempo Basket'], axis=1, inplace=True)

# %%
print(df.columns)
data.tail()
# Out:
# Index(['artists', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'popularity', 'key', 'mode', 'count', 'genres'],
#       dtype='object')
#         acousticness                         artists  danceability  \
# 165750      0.009207  DJ Combo', 'Sander-7', 'Tony T      0.801619
# 165751      0.798193                    Alessia Cara      0.434211
# 165752      0.809237                       Roger Fly      0.679150
# 165753      0.923695                    Taylor Swift      0.467611
# 165754      0.239960                       Roger Fly      0.685223
#
#         duration_ms  energy  explicit                      id  \
# 165750       147615   0.866         0  46LhBf6TvYjZU2SMvGZAbn
# 165751       144720   0.211         0  7tue2Wemjd0FZzRtDrQFZd
# 165752       218147   0.589         0  48Qj61hOdYmUCFJbpQ29Ob
# 165753       244000   0.240         1  1gcyHQpBQ1lfXGdhZmWrHP
# ...

# %% [markdown]
# ##  Plotting Histograms of all Features

# %%
plt.style.use('fivethirtyeight')
# sns.distplot(df['acousticness', bins=50)
df.hist(figsize=(20, 20), bins=25, alpha=.5)

plt.show()
# Out:
# c:\users\dabor\.virtualenvs\spotify-1-brdsutq_\lib\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
df.corr()
# Out:
#                   acousticness  danceability  duration_ms    energy  \
# acousticness          1.000000     -0.424457    -0.105510 -0.812479
# danceability         -0.424457      1.000000    -0.017983  0.373747
# duration_ms          -0.105510     -0.017983     1.000000  0.050462
# energy               -0.812479      0.373747     0.050462  1.000000
# instrumentalness      0.052731     -0.144439     0.157470 -0.067007
# liveness              0.007735     -0.128974    -0.032482  0.119412
# loudness             -0.630304      0.442657    -0.031587  0.790035
# speechiness           0.006280      0.228174     0.005818  0.026715
# tempo                -0.309368      0.130781     0.003820  0.348772
# valence              -0.131148      0.517621    -0.184973  0.286840
# popularity           -0.233738      0.107888    -0.068137  0.136728
# key                  -0.051619      0.043218     0.012278  0.050529
# mode                  0.163035     -0.110953    -0.052430 -0.150864
# ...

# %% [markdown]
# ## Function that averages each feature for each year

# %%
def avg_each_year(df):
    
    sequential = df.copy()
    group = sequential.groupby("year")
    average_each_year = group.mean()
    average_each_year = average_each_year.reset_index()
    
    return average_each_year

average_year = avg_each_year(data)
avg_year = average_year.copy()
avg_year.tail()
# Out:
#      year  acousticness  danceability    duration_ms    energy  explicit  \
# 97   2017      0.204441      0.588783  243109.757459  0.687314  0.227623
# 98   2018      0.218971      0.609683  227036.122209  0.662899  0.238935
# 99   2019      0.261926      0.612694  225020.283468  0.628102  0.241240
# 100  2020      0.203985      0.610280  218987.392017  0.674246  0.188081
# 101  2021      0.302811      0.664717  219448.235971  0.623081  0.109353
#
#      instrumentalness       key  liveness  loudness      mode  popularity  \
# 97           0.242964  5.320019  0.231381  0.133735  0.608277   32.765159
# 98           0.230534  5.418723  0.227466  0.134472  0.580885   28.972973
# 99           0.218667  5.353998  0.216381  0.141681  0.600180   33.526954
# 100          0.242914  5.351832  0.239556  0.133309  0.590487   27.084746
# 101          0.268138  5.334532  0.166856  0.141319  0.586331    9.292086
#
#      speechiness     tempo   valence          index  duration_sec
# ...

# %% [markdown]
# ## Line Plots

# %%
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(20, 8))  # chart 19.5in x 8
ax.set_title("A Few Key Features (after scaling)", 
             fontsize=14, fontweight='bold')

plt.plot(avg_year['year'],avg_year['acousticness'], color='black', label='acousticness')
plt.plot(avg_year['year'], avg_year['danceability'], color='red', label='danceability')
plt.plot(avg_year['year'], avg_year['energy'], color='blue', label='energy')
plt.plot(avg_year['year'], avg_year['instrumentalness'], color='purple', label='instrumentalness', linestyle="--")
plt.plot(avg_year['year'], avg_year['loudness'], color='c', label='loudness')
plt.plot(avg_year['year'], avg_year['valence'], color='green', label='valence')

plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## Correlation Plots

# %%
# Inspect correlations between features
plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(),annot=True);
